# %% [markdown]
# # open ai account setup:
# https://platform.openai.com/login
#
#
# https://developers.openai.com/api/docs?lang=python

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from openai import OpenAI

client = OpenAI()

response = client.responses.create(
    model="gpt-5.6", 
    input="Write a short bedtime story about a unicorn."
)

print(response.output_text)
# Out:
# Once upon a moonlit night, a little unicorn named Luma noticed that one star was missing from the sky.
#
# She followed a trail of silver sparkles through the quiet forest and found the star tangled in a sleepy willow tree. With a gentle touch of her horn, Luma lifted it free.
#
# “Thank you,” whispered the star. “Now everyone can find their dreams.”
#
# It floated back into the sky and shone brighter than ever. Luma curled up beneath the willow, wrapped her tail around herself, and closed her eyes.
#
# Above her, the stars twinkled a soft goodnight.
#
# And soon, the whole forest was dreaming.

# %%
response.output_text
# Out:
# 'Once upon a moonlit night, a little unicorn named Luma noticed that one star was missing from the sky.\n\nShe followed a trail of silver sparkles through the quiet forest and found the star tangled in a sleepy willow tree. With a gentle touch of her horn, Luma lifted it free.\n\n“Thank you,” whispered the star. “Now everyone can find their dreams.”\n\nIt floated back into the sky and shone brighter than ever. Luma curled up beneath the willow, wrapped her tail around herself, and closed her eyes.\n\nAbove her, the stars twinkled a soft goodnight.\n\nAnd soon, the whole forest was dreaming.'

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser


llm = ChatOpenAI(
    model = "gpt-4o-mini"
)

response = llm.invoke("hi")

# %%
response.content
# Out:
# 'Hello! How can I assist you today?'

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser


llm = ChatOpenAI(
    model = "gpt-4o-mini"
)

question = input("Enter your question: ")

prompt = ChatPromptTemplate.from_messages(
    [
    ("system", "You are a helpful assistant that can answer questions and help with tasks."),
    ("user", f"Question: {question}"),
    ]
)

output_parser = StrOutputParser()



chain = prompt| llm | output_parser

result = chain.invoke({})
print(result)
# Out:
# "The Toxic Avenger," released in 1984, is a cult classic horror-comedy film directed by Lloyd Kaufman and produced by Troma Entertainment. The movie follows the story of Melvin Ferd, a timid mop boy who becomes a hideously deformed creature after falling into a vat of toxic waste. After his transformation, he becomes the titular "Toxic Avenger," fighting crime and taking on corrupt individuals in his town.
#
# The film is known for its over-the-top humor, graphic violence, and satirical commentary on environmental issues and societal norms. While it received mixed reviews upon its release, it has since gained a significant following and is considered a landmark in the independent film and exploitation genres. The film's tone combines horror and comedy in a unique way, making it a memorable piece of pop culture.
#
# If you meant a different film or have specific aspects of the movie you want to discuss, please let me know!

# %%
# Out:
# 'The capital of France is Paris.'
