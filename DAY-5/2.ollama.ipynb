# %% [markdown]
# ### Ollama downloading doc:
# https://ollama.com/
#
# ### Ollama listing the model in your cli
# ```
# /Volumes/ManojData/github/ITK-FREE-GENAI-SERIES-NOTES main !2 ?2 > ollama list                                                                                                                                              15s 05:08:34 PM
# NAME               ID              SIZE      MODIFIED
# llama3.1:latest    46e0c10c039e    4.9 GB    4 months ago
# ```
#
# ```
# ollama run llama3.1
# ```

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model = "llama3.1:latest"
)

result=llm.invoke("hi")
result.content
# Out:
# "How's it going? Is there something I can help you with or would you like to chat?"

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser


llm = ChatOllama(
    model = "llama3.1:latest"
)


question = input("Enter your question: ")

prompt = ChatPromptTemplate.from_messages(
    [
    ("system", "You are a helpful assistant that can answer questions and help with tasks."),
    ("user", f"Question: {question}"),
    ]
)

output_parser = StrOutputParser()



chain = prompt| llm | output_parser

result = chain.invoke({})
print(result)
# Out:
# A Forward-Deployed Engineer (FDE) role is a type of technical position that requires an engineer to work on-site or in a remote location, often in a rugged or challenging environment. Here's an overview of the role:
#
# **Responsibilities:**
#
# As a Forward-Deployed Engineer, your primary responsibilities may include:
#
# 1. **Troubleshooting and Repair**: Troubleshoot and repair complex technical issues in various systems, including software, hardware, and network infrastructure.
# 2. **System Integration**: Integrate new systems, equipment, or software into existing infrastructure, ensuring seamless operation and minimal downtime.
# 3. **Training and Support**: Provide training and support to local personnel on the use and maintenance of technical systems.
# 4. **Emergency Response**: Be prepared to respond to emergency situations, such as equipment failures or system crashes, in a timely and effective manner.
# 5. **Documentation and Reporting**: Maintain accurate records and reports of system performance, issues, and repairs.
#
# **Key Skills and Qualifications:**
#
# To be successful in a Forward-Deployed Engineer role, you should possess:
#
# 1. **Technical expertise**: Strong knowledge of software, hardware, and networking principles, as well as experience with specific systems and technologies.
# 2. **Problem-solving skills**: Ability to analyze complex technical issues and develop effective solutions.
# 3. **Communication skills**: Excellent verbal and written communication skills to work effectively with local personnel and stakeholders.
# 4. **Adaptability**: Willingness to work in challenging environments, adapt to changing circumstances, and prioritize tasks in high-pressure situations.
# 5. **Physical demands**: Ability to work in a physically demanding environment, including extreme temperatures, remote locations, and potentially hazardous conditions.
#
# **Industries and Environments:**
#
# Forward-Deployed Engineers can be found in various industries, including:
#
# 1. **Military and Defense**: Supporting military operations, bases, and equipment.
# 2. **Energy and Utilities**: Working in remote or hard-to-reach locations, such as oil rigs or power plants.
# 3. **Telecommunications**: Deploying and maintaining network infrastructure in rural or challenging areas.
# 4. **Aerospace**: Supporting space exploration and satellite operations.
# 5. **Emergency Response**: Providing technical support during natural disasters or emergency situations.
#
# **Challenges and Rewards:**
#
# Working as a Forward-Deployed Engineer can be challenging due to:
#
# 1. **Remote or isolated locations**: Limited access to resources, amenities, and support.
# 2. **Unpredictable environment**: Unforeseen technical issues, weather conditions, or emergency situations.
# 3. **Physical demands**: Working in extreme temperatures, hazardous conditions, or physically demanding environments.
#
# However, the rewards of this role can be significant, including:
#
# 1. **Opportunities for adventure**: Working in unique and challenging environments.
# 2. **Sense of purpose**: Supporting critical operations, such as military or emergency response efforts.
# 3. **Personal growth**: Developing skills, expertise, and confidence in a dynamic and fast-paced environment.
#
# I hope this provides a comprehensive overview of the Forward-Deployed Engineer role! Do you have any specific questions or areas you'd like me to expand on?
